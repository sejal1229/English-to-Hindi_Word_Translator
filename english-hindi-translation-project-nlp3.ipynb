# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import string
import re

from keras.models import Model
from keras.layers import Input, LSTM, Dense

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/englishhindi-translation-dataset-iit-bombay/hindi_english_parallel.csv

# %% [markdown]
# ## 1. Loading data

# %%
df = pd.read_csv("/kaggle/input/englishhindi-translation-dataset-iit-bombay/hindi_english_parallel.csv")

# %%
df.head()
# Out:
#                                                hindi  \
# 0    अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# 1                    एक्सेर्साइसर पहुंचनीयता अन्वेषक
# 2              निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# 3               ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# 4  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से नि...
#
#                                           english
# 0  Give your application an accessibility workout
# 1               Accerciser Accessibility Explorer
# 2  The default plugin layout for the bottom panel
# 3     The default plugin layout for the top panel
# 4  A list of plugins that are disabled by default

# %%
ndf = df.dropna(axis=0)

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1555727 entries, 0 to 1561839
# Data columns (total 2 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   hindi    1555727 non-null  object
#  1   english  1555727 non-null  object
# dtypes: object(2)
# memory usage: 35.6+ MB

# %%
ndf.head()
# Out:
#                                                hindi  \
# 0    अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# 1                    एक्सेर्साइसर पहुंचनीयता अन्वेषक
# 2              निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# 3               ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# 4  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से नि...
#
#                                           english
# 0  Give your application an accessibility workout
# 1               Accerciser Accessibility Explorer
# 2  The default plugin layout for the bottom panel
# 3     The default plugin layout for the top panel
# 4  A list of plugins that are disabled by default

# %%
ndf.iloc[0,:]
# Out:
# hindi      अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# english     Give your application an accessibility workout
# Name: 0, dtype: object

# %% [markdown]
# ## 2. Data cleaning

# %%
def data_cleaning(text):
    sample = text
    sample = [char for char in text if char not in string.punctuation]
    return sample

input_text = ndf['hindi'][:10000].apply(data_cleaning)
target_text = ndf['english'][:10000].apply(data_cleaning)

# %% [markdown]
# ## 3. Tokenizing the data

# %%
input_char = set()
target_char = set()

# total unique words in hindi corpus
for line in input_text:
    for char in line:
        if char not in input_char:
            if char not in string.punctuation:
                input_char.add(char)
        
# total unique words in english corpus
for line2 in target_text:
    for char2 in line2:
        if char2 not in target_char:
            if char2 not in string.punctuation:
                target_char.add(char2)

# %%
# find chars to encode and max encoder seq length
input_characters = sorted(list(input_char))
target_characters = sorted(list(target_char))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_text])
max_decoder_seq_length = max([len(txt) for txt in target_text])

print('Number of samples:', len(input_text))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 125
# Number of unique output tokens: 67
# Max sequence length for inputs: 272
# Max sequence length for outputs: 224

# %%
# indexing the input and target tokens
input_token_index = dict([(char,i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char,i) for i, char in enumerate(target_characters)])

# %%
# encoder and decoder input data 
encoder_input_data = np.zeros(
    (len(input_text), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_text), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_text), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
# shape of input encoder data
encoder_input_data.shape
# Out:
# (10000, 272, 125)

# %%
# shape of output decoder data
decoder_target_data.shape
# Out:
# (10000, 224, 67)

# %%
# create encoder and decoder train the translation model
for i, (input_text, target_text) in enumerate(zip(input_text, target_text)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %% [markdown]
# ## 4. Modeling and evaluation

# %%
batch_size = 64  # Batch size for training.
epochs = 50  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 20000  # Number of samples to train on.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]
# Out:
# 2023-01-31 13:10:37.020296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.021362: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.195626: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.196524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.197291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.198067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.201338: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-31 13:10:37.430666: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.431590: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.432426: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.433370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.434105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:37.434818: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:41.522235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:41.523179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:41.523937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:41.524727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:41.525505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:41.526215: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-01-31 13:10:41.530797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:10:41.531473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 125)]  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 67)]   0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 256), (None, 391168      input_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, None, 256),  331776      input_2[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 67)     17219       lstm_1[0][0]
# ==================================================================================================
# Total params: 740,163
# Trainable params: 740,163
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,batch_size=batch_size,epochs=epochs,validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# 2023-01-31 13:10:42.462148: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1088000000 exceeds 10% of free system memory.
# 2023-01-31 13:10:44.720671: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1088000000 exceeds 10% of free system memory.
# 2023-01-31 13:10:46.379503: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2023-01-31 13:10:50.318375: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 125/125 [==============================] - 16s 74ms/step - loss: 0.3830 - accuracy: 0.9247 - val_loss: 0.1817 - val_accuracy: 0.9547
# Epoch 2/50
# 125/125 [==============================] - 8s 61ms/step - loss: 0.2823 - accuracy: 0.9335 - val_loss: 0.1683 - val_accuracy: 0.9563
# Epoch 3/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.2394 - accuracy: 0.9378 - val_loss: 0.1572 - val_accuracy: 0.9584
# Epoch 4/50
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2050 - accuracy: 0.9441 - val_loss: 0.1495 - val_accuracy: 0.9603
# Epoch 5/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.1826 - accuracy: 0.9504 - val_loss: 0.1455 - val_accuracy: 0.9610
# Epoch 6/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.1641 - accuracy: 0.9553 - val_loss: 0.1383 - val_accuracy: 0.9632
# Epoch 7/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.1494 - accuracy: 0.9590 - val_loss: 0.1344 - val_accuracy: 0.9636
# Epoch 8/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.1370 - accuracy: 0.9621 - val_loss: 0.1300 - val_accuracy: 0.9644
# Epoch 9/50
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1258 - accuracy: 0.9650 - val_loss: 0.1247 - val_accuracy: 0.9668
# Epoch 10/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.1158 - accuracy: 0.9677 - val_loss: 0.1215 - val_accuracy: 0.9672
# Epoch 11/50
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1067 - accuracy: 0.9703 - val_loss: 0.1173 - val_accuracy: 0.9682
# Epoch 12/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0985 - accuracy: 0.9727 - val_loss: 0.1156 - val_accuracy: 0.9688
# Epoch 13/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0911 - accuracy: 0.9749 - val_loss: 0.1113 - val_accuracy: 0.9700
# Epoch 14/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0845 - accuracy: 0.9768 - val_loss: 0.1092 - val_accuracy: 0.9704
# Epoch 15/50
# 125/125 [==============================] - 6s 48ms/step - loss: 0.0787 - accuracy: 0.9786 - val_loss: 0.1051 - val_accuracy: 0.9715
# Epoch 16/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0734 - accuracy: 0.9801 - val_loss: 0.1022 - val_accuracy: 0.9727
# Epoch 17/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0689 - accuracy: 0.9813 - val_loss: 0.1010 - val_accuracy: 0.9727
# Epoch 18/50
# 125/125 [==============================] - 6s 52ms/step - loss: 0.0649 - accuracy: 0.9824 - val_loss: 0.0992 - val_accuracy: 0.9735
# Epoch 19/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0613 - accuracy: 0.9834 - val_loss: 0.0950 - val_accuracy: 0.9747
# Epoch 20/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0581 - accuracy: 0.9842 - val_loss: 0.0927 - val_accuracy: 0.9756
# Epoch 21/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0552 - accuracy: 0.9849 - val_loss: 0.0901 - val_accuracy: 0.9763
# Epoch 22/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0527 - accuracy: 0.9855 - val_loss: 0.0886 - val_accuracy: 0.9764
# Epoch 23/50
# 125/125 [==============================] - 7s 55ms/step - loss: 0.0505 - accuracy: 0.9860 - val_loss: 0.0875 - val_accuracy: 0.9764
# Epoch 24/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0484 - accuracy: 0.9866 - val_loss: 0.0848 - val_accuracy: 0.9774
# Epoch 25/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0465 - accuracy: 0.9870 - val_loss: 0.0825 - val_accuracy: 0.9781
# Epoch 26/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0448 - accuracy: 0.9874 - val_loss: 0.0815 - val_accuracy: 0.9788
# Epoch 27/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0433 - accuracy: 0.9878 - val_loss: 0.0795 - val_accuracy: 0.9793
# Epoch 28/50
# 125/125 [==============================] - 7s 54ms/step - loss: 0.0419 - accuracy: 0.9881 - val_loss: 0.0779 - val_accuracy: 0.9799
# Epoch 29/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0406 - accuracy: 0.9883 - val_loss: 0.0759 - val_accuracy: 0.9806
# Epoch 30/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0392 - accuracy: 0.9887 - val_loss: 0.0755 - val_accuracy: 0.9802
# Epoch 31/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0382 - accuracy: 0.9889 - val_loss: 0.0746 - val_accuracy: 0.9805
# Epoch 32/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0372 - accuracy: 0.9891 - val_loss: 0.0729 - val_accuracy: 0.9812
# Epoch 33/50
# 125/125 [==============================] - 6s 52ms/step - loss: 0.0365 - accuracy: 0.9893 - val_loss: 0.0720 - val_accuracy: 0.9816
# Epoch 34/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0354 - accuracy: 0.9895 - val_loss: 0.0707 - val_accuracy: 0.9819
# Epoch 35/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0345 - accuracy: 0.9897 - val_loss: 0.0694 - val_accuracy: 0.9826
# Epoch 36/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0339 - accuracy: 0.9899 - val_loss: 0.0690 - val_accuracy: 0.9825
# Epoch 37/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0331 - accuracy: 0.9900 - val_loss: 0.0680 - val_accuracy: 0.9826
# Epoch 38/50
# 125/125 [==============================] - 7s 52ms/step - loss: 0.0324 - accuracy: 0.9902 - val_loss: 0.0682 - val_accuracy: 0.9826
# Epoch 39/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0324 - accuracy: 0.9901 - val_loss: 0.0678 - val_accuracy: 0.9827
# Epoch 40/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0314 - accuracy: 0.9904 - val_loss: 0.0656 - val_accuracy: 0.9835
# Epoch 41/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0309 - accuracy: 0.9905 - val_loss: 0.0654 - val_accuracy: 0.9836
# Epoch 42/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0304 - accuracy: 0.9906 - val_loss: 0.0648 - val_accuracy: 0.9838
# Epoch 43/50
# 125/125 [==============================] - 7s 52ms/step - loss: 0.0299 - accuracy: 0.9907 - val_loss: 0.0640 - val_accuracy: 0.9840
# Epoch 44/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0294 - accuracy: 0.9908 - val_loss: 0.0630 - val_accuracy: 0.9844
# Epoch 45/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0289 - accuracy: 0.9910 - val_loss: 0.0634 - val_accuracy: 0.9841
# Epoch 46/50
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0285 - accuracy: 0.9910 - val_loss: 0.0629 - val_accuracy: 0.9843
# Epoch 47/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0281 - accuracy: 0.9911 - val_loss: 0.0620 - val_accuracy: 0.9844
# Epoch 48/50
# 125/125 [==============================] - 6s 52ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.0619 - val_accuracy: 0.9849
# Epoch 49/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.0274 - accuracy: 0.9912 - val_loss: 0.0606 - val_accuracy: 0.9849
# Epoch 50/50
# 125/125 [==============================] - 6s 51ms/step - loss: 0.0271 - accuracy: 0.9912 - val_loss: 0.0603 - val_accuracy: 0.9848

# %% [markdown]
# **Observations:**
#
# 1. We can see train accuray of the model is around 99% while validation accuracy is around 98%.
#
# 2. We trained model on NVIDIA T4 GPUs to speed up the computations. It uses RAPIDS cuDNN at the backend to optimize the computations.
